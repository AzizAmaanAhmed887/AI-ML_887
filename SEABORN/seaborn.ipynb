# %%
# Import seaborn
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")
print(df.shape)  # kitne rows/cols hain
print(df.dtypes)  # numeric vs categorical columns
print(df.isnull().sum())  # null values kitne hain
# # Tip vs Total bill
# sns.scatterplot(data=df, x="total_bill", y="tip", hue="sex")
# plt.show()

# %%
flights = sns.load_dataset("flights")

flights

# %%
print(df.head())

# %%
sns.relplot(
    data=df,
    x="total_bill", y="tip",
    kind="scatter",
    hue="sex",  # color se gender
    size="size",  # party size = point size
    style="smoker",  # shape se smoker/non-smoker
    col="time",  # Lunch | Dinner — 2 subplots
    palette="Set2",
    alpha=0.7,
    height=4, aspect=1.2
)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

tips = sns.load_dataset('tips')
print(tips.head())  # Preview data [web:1]

# %%
tips = sns.load_dataset("tips")
sns.relplot(data=tips, x="total_bill", y="tip", hue='smoker', col="sex", style='day')

# %%
flights = sns.load_dataset("flights")
flights.head()

# %%
sns.lineplot(data=flights, x="year", y="passengers")

# %%
# Categorical Plots

import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")

sns.catplot(data=df, x="day", y="total_bill", kind="box")
plt.show()

# %%
sns.catplot(data=df, x="day", y="total_bill", kind="bar")
plt.show()

# %%
sns.boxplot(data=df, x="day", y="tip", hue="smoker")

# %%
sns.barplot(data=df, x='day', y='tip', hue='smoker')

# %%
# Distribution plots

penguins=sns.load_dataset("penguins")

sns.histplot(
    data=penguins,
    x="body_mass_g",
    bins=30,
)
